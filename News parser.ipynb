# %% [markdown]
# ### Урок 4. Парсинг HTML. XPath

# %% [markdown]
# Написать приложение, которое собирает основные новости с сайтов mail.ru, lenta.ru, yandex-новости. Для парсинга использовать XPath. Структура данных должна содержать:
#
# - название источника;
# - наименование новости;
# - ссылку на новость;
# - дата публикации.

# %%
from lxml import html
import requests
import pandas as pd
from pymongo import MongoClient
from datetime import datetime, timedelta

# %%
def get_lenta_news():
    news = []
    url = 'https://m.lenta.ru/parts/news/'
    response = requests.get(url)
    root = html.fromstring(response.text)
    root.make_links_absolute(url)
    articles = root.xpath("//li[@class='parts-page__item']")
    for article in articles:
        source = 'lenta.ru'
        title = str(article.xpath(".//div[@class='card-mini__title']/text()")[0])
        link = str(article.xpath(".//a/@href")[0])
        date = str(article.xpath(".//time/text()")[0])
        date = str(datetime.today().date()) + ' ' + date
        item = {
            'source': source,
            'title': title,
            'link': link,
            'date': date
        }
        news.append(item)

    return news

# %%
def get_yandex_news():
    news = []
    url = 'https://yandex.ru/news'
    response = requests.get(url)
    root = html.fromstring(response.text)
    articles = root.xpath("//article")
    for article in articles:
        source = str(article.xpath(".//a[@class='mg-card__source-link']/text()")[0])
        title = str(article.xpath(".//h2/text()")[0])
        link = str(article.xpath(".//a[@class='mg-card__link']/@href")[0])
        date = article.xpath(".//span[@class='mg-card-source__time']/text()")[0].split(' ')
        if date[0] == 'вчера':
            yesterday = datetime.today().date() - timedelta(days=1)
            date = str(yesterday) + ' ' + str(date[2])
        else:    
            date = str(datetime.today().date()) + ' ' + str(date[0])
        item = {
            'source': source,
            'title': title,
            'link': link,
            'date': date
        }
        news.append(item)

    return news

# %%
def get_mail_news():
    news = []
    url = 'https://news.mail.ru/'
    response = requests.get(url)
    root = html.fromstring(response.text)
    articles = root.xpath("//div[contains(@class, 'js-ago-wrapper')] | //li[@class='list__item']")
    date_format = '%Y-%m-%dT%H:%M:%S%z'
    
    for article in articles:
        title = str(article.xpath(".//a[contains(@class, 'newsitem__title')]/span/text() | .//a/text() | .//a/span/text()")[0])
        link = str(article.xpath(".//a/@href")[0])
        linkhtml = html.fromstring(requests.get(link).text)
        source = str(linkhtml.xpath("//a[contains(@class, 'breadcrumbs__link')]/span[@class='link__text']/text()")[0])
        date = linkhtml.xpath("//span[@class='note__text breadcrumbs__text js-ago']/@datetime")
        date = datetime.strptime(str(date[0]), date_format).strftime('%Y-%m-%d %H:%M') if date else 'Неизвестно'
        item = {
            'source': source,
            'title': title,
            'link': link,
            'date': date
        }
        news.append(item)

    return news

# %%
lentanews = get_lenta_news()
yandexnews = get_yandex_news()
mailnews = get_mail_news()
news = lentanews + yandexnews + mailnews

client = MongoClient('127.0.0.1', 27017)
db = client['news']
news_collection = db.news_collection
news_collection.insert_many(news)

# %%
df = pd.DataFrame(news_collection.find()).drop('_id', 1)
df.sample(30)
# Out:
#                     source                                              title  \
# 84         Автоновости дня  Экспорт автомобилей из Южной Кореи упал в сент...
# 65                    ТАСС     Вышел трейлер «Бэтмена» с Робертом Паттинсоном
# 39                    ТАСС  Песков: Запад обвиняет Россию в росте цен на г...
# 78            Planet Today  В Японии с помощью солнечной энергии добыли бо...
# 88                 Смотрим     Кабо-Верде выдала США венесуэльского дипломата
# 67             Фонтанка.Ру  Концерт Васи Обломова в Петербурге не был согл...
# 24             РИА Новости  Володин предложил ввести процедуру отзыва Нобе...
# 91   МК.RU Санкт-Петербург  Суточная заболеваемость COVID в Петербурге вно...
# 82                Автостат  В России начались продажи кроссовера Kia Soren...
# 104               Известия  Вильфанд предупредил о мокром снеге в европейс...
# 6                 lenta.ru  Стало известно о состоянии вернувшегося с МКС ...
# 103               Мослента  Собянин поздравил работников дорожного хозяйст...
# 102               Мослента  Мать отравившегося в подмосковной школе ребенк...
# 97                Известия  7-процентный барьер: ключевой ставке прописали...
# 99               Газета.Ру  Эксперты считают, что адресные соцвыплаты не р...
# 73                  3DNews  У процессоров Intel Alder Lake могут возникнут...
# 25            47channel.ru  В Ленинградской области 301 житель заболел кор...
# 11                lenta.ru  Свидетельница конфликта в московском метро поо...
# 26            47channel.ru  МЧС: с 17 по 19 октября в Ленобласти ожидается...
# 34             РИА Новости  Минюст США подтвердил экстрадицию из Кабо-Верд...
# 5                 lenta.ru                    ЦСКА обыграл «Урал» в матче РПЛ
# 44                Известия              В России впервые отмечается День отца
# 2                 lenta.ru  Зюганов призвал посадить Горбачева за развал СССР
# 83         Автоновости дня  Седаны Hyundai Solaris и KIA Rio дорожают на в...
# 29                 ЛенТВ24  В Шлиссельбурге проходит праздник «Самый лучши...
# 14                lenta.ru  Нурмагомедов поддержал Исмаилова после нокаута...
# 16                lenta.ru  В российском цирке объяснили нападение медведя...
# 89                     РБК  Киберкоманда из России впервые вышла в финал T...
# 15                lenta.ru  В Москве умер бывший сенатор от Астраханской о...
# 81         Автоновости дня  Прайм: средняя цена нового автомобиля в России...
#
#                                                   link              date
# 84   https://yandex.ru/news/story/EHksport_avtomobi...  2021-10-17 15:57
# 65   https://yandex.ru/news/story/Vyshel_trejler_Be...  2021-10-17 15:53
# 39   https://yandex.ru/news/story/Peskov_Zapad_obvi...  2021-10-17 15:38
# 78   https://yandex.ru/news/story/VYAponii_spomoshh...  2021-10-17 15:51
# 88             https://news.mail.ru/incident/48379037/  2021-10-17 00:42
# 67   https://yandex.ru/news/story/Koncert_Vasi_Oblo...  2021-10-17 15:34
# 24   https://yandex.ru/news/story/Volodin_predlozhi...  2021-10-17 16:08
# 91              https://news.mail.ru/society/48374134/  2021-10-16 11:45
# 82   https://yandex.ru/news/story/VRossii_nachalis_...  2021-10-17 11:42
# 104             https://news.mail.ru/society/48381739/  2021-10-17 12:16
# 6       https://m.lenta.ru/news/2021/10/17/sostoyanie/  2021-10-17 15:58
# 103             https://news.mail.ru/society/48382007/  2021-10-17 12:30
# 102             https://news.mail.ru/society/48381054/  2021-10-17 12:33
# 97            https://news.mail.ru/economics/48379100/  2021-10-17 10:03
# 99            https://news.mail.ru/economics/48377843/  2021-10-16 19:54
# 73   https://yandex.ru/news/story/Uprocessorov_Inte...  2021-10-17 15:52
# 25   https://yandex.ru/news/story/VLeningradskoj_ob...  2021-10-17 15:16
# 11   https://m.lenta.ru/news/2021/10/17/metro_confl...  2021-10-17 15:32
# 26   https://yandex.ru/news/story/MCHS_s17_po19_okt...  2021-10-17 15:38
# 34   https://yandex.ru/news/story/Minyust_SSHA_podt...  2021-10-17 15:53
# 5             https://m.lenta.ru/news/2021/10/17/cska/  2021-10-17 16:00
# 44   https://yandex.ru/news/story/VRossii_vpervye_o...  2021-10-17 16:16
# 2    https://m.lenta.ru/news/2021/10/17/razvalili_s...  2021-10-17 16:17
# 83   https://yandex.ru/news/story/Sedany_Hyundai_So...  2021-10-17 14:43
# 29   https://yandex.ru/news/story/VSHlisselburge_pr...  2021-10-17 15:49
# 14    https://m.lenta.ru/news/2021/10/17/nurmagomedov/  2021-10-17 15:25
# 16          https://m.lenta.ru/news/2021/10/17/medved/  2021-10-17 15:16
# 89      https://sportmail.ru/news/cybersport/48382962/  2021-10-17 14:38
# 15            https://m.lenta.ru/news/2021/10/17/astr/  2021-10-17 15:22
# 81   https://yandex.ru/news/story/Prajm_srednyaya_c...  2021-10-16 23:55
